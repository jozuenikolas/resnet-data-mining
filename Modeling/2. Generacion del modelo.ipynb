# %% [markdown]
# <h1 style="text-align:center;"><strong>Generación del Modelo<strong></h1>

# %% [markdown]
# ### 1) Importar librerías

# %%
import pandas as pd
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ### 2) Cargar el corpus

# %% [markdown]
# #### Definir el path del Corpus

# %%
basePath = 'resources/corpus/'
modelo = 'tf-idf'
version = 'v10.0'
corpusPath = basePath+'corpus-'+modelo+"-"+version+".pkl"

# %% [markdown]
# #### Leer el corpus

# %%
with open(corpusPath, "rb") as fp: 
    corpus = pickle.load(fp)

# %%
len(corpus)
# Out:
# 37569

# %%
corpus[:2]
# Out:
#         doc_id                                   preprocessed_doc
# 0  57781304700  metamodeling audio signals design process enco...
# 1  57581708700  facility layout design textile msmes literatur...

# %%
len(corpus['preprocessed_doc'].to_list())
# Out:
# 37569

# %% [markdown]
# ### 3) Generación del modelo

# %% [markdown]
# #### Instanciar el modelo tf-idf

# %%
tfidf = TfidfVectorizer(norm='l2', smooth_idf=True, sublinear_tf=True)

# %% [markdown]
# #### Obtener la matrix tf-idf del método fit_transform()

# %%
matrix = tfidf.fit_transform(corpus['preprocessed_doc'].to_list())

# %% [markdown]
# #### Obtener el vocabulario

# %%
len(tfidf.get_feature_names_out())
# Out:
# 120632

# %%
tfidf.vocabulary_
# Out:
# {'metamodeling': 69826,
#  'audio': 14854,
#  'signals': 101427,
#  'design': 33979,
#  'process': 89625,
#  'encounter': 40003,
#  'sound': 103242,
#  'changing': 23912,
#  'forms': 46263,
#  'context': 28601,
#  'following': 45982,
#  'work': 119107,
#  'arises': 13511,
#  'exploratory': 43253,
#  'interest': 58811,
#  'around': 13616,
#  'order': 80034,
#  'able': 7411,
#  'structure': 105540,
#  'fictional': 44854,
#  'architectural': 13288,
#  'envelopes': 40708,
#  'reactive': 93332,
#  'nature': 75182,
#  'whose': 118667,
#  'materialization': 68219,
#  'achieved': 7969,
#  'digital': 35001,
#  'visualization': 117205,
#  'techniques': 108525,
#  'generative': 48290,
#  'software': 102861,
#  'art': 13684,
#  'research': 95168,
#  'implies': 56883,
#  'interdisciplinary': 58801,
#  'development': 34268,
#  'different': 34898,
#  'categories': 22574,
#  'knowledge': 62279,
#  'unconventional': 114105,
#  'processes': 89630,
#  'built': 20286,
#  'activated': 8216,
#  'element': 39300,
#  'generates': 48283,
#  'random': 92927,
#  'values': 115869,
#  'information': 57841,
#  'direct': 35438,
#  'impact': 56755,
#  'configuration': 27971,
#  'behavior': 16854,
#  'form': 46200,
#  'environment': 40726,
#  'today': 110901,
#  'boundaries': 19333,
#  'define': 32946,
#  'creative': 30058,
#  'territories': 109205,
#  'increasingly': 57294,
#  'flexible': 45490,
#  'adaptive': 8382,
#  'allows': 10251,
#  'establishing': 41850,
#  'networks': 75983,
#  'expand': 43095,
#  'ranges': 92948,
#  'action': 8205,
#  'activities': 8238,
#  'experimental': 43175,
#  'spaces': 103362,
#  'facility': 43702,
#  'layout': 63581,
#  'textile': 109424,
#  'msmes': 73267,
#  'literature': 65174,
#  'review': 95805,
#  'resilient': 95265,
#  'indicators': 57432,
#  'capacity': 21693,
#  'respond': 95377,
#  'adapt': 8364,
#  'risks': 96471,
#  'problems': 89577,
#  'organization': 80124,
#  'critical': 30269,
#  'business': 20494,
#  'success': 106317,
#  'type': 113450,
#  'weakness': 118238,
#  'causes': 22732,
#  'inefficient': 57601,
#  'use': 115410,
#  'resources': 95341,
#  'contrary': 28727,
#  'facilities': 43700,
#  'ensure': 40491,
#  'continuity': 28659,
#  'operations': 79724,
#  'face': 43666,
#  'disruptive': 35937,
#  'events': 42581,
#  'significantly': 101451,
#  'harm': 51677,
#  'company': 27313,
#  'however': 54156,
#  'flexibility': 45488,
#  'optimization': 79910,
#  'approaches': 12932,
#  'enhance': 40358,
#  'synthesizes': 107554,
#  'variables': 115966,
#  'greater': 50291,
#  'three': 110149,
#  'areas': 13362,
#  'resilience': 95263,
#  'industry': 57584,
#  'problem': 89563,
#  'flp': 45676,
#  'systematic': 107609,
#  'conducted': 27896,
#  'considering': 28337,
#  '99': 7006,
#  'studies': 105582,
#  'published': 91165,
#  '2010': 2465,
#  '2021': 2502,
#  'documents': 36442,
#  'analyzed': 11251,
#  'using': 115437,
#  'atlas': 14587,
#  'ti': 110319,
#  '4w': 4887,
#  'analysis': 11230,
#  'questions': 92295,
#  'posed': 88001,
#  'pico': 85873,
#  'strategy': 105311,
#  'findings': 45069,
#  'indicate': 57422,
#  'scientific': 99153,
#  'regarding': 94244,
#  'increasing': 57293,
#  'last': 63347,
#  'six': 102003,
#  'years': 119904,
#  'specifically': 103544,
#  'evaluation': 42530,
#  'methods': 70002,
#  'identify': 55961,
#  'factors': 43728,
#  'fuzzy': 47372,
#  'mathematical': 68241,
#  'models': 72006,
#  'also': 10385,
#  'highlighted': 53206,
#  'scarcity': 98856,
#  'importance': 56897,
#  'accurate': 7831,
#  'model': 71984,
#  'finally': 45032,
#  'set': 100653,
#  'possible': 88078,
#  'approach': 12929,
#  'based': 16356,
#  'proposed': 90182,
#  'management': 67413,
#  'integrated': 58572,
#  'biosafety': 18190,
#  'parameters': 82351,
#  'case': 22361,
#  'study': 105588,
#  'smes': 102435,
#  'manufacturing': 67663,
#  'rest': 95416,
#  'footwear': 46051,
#  'province': 90500,
#  'tungurahua': 113177,
#  'aimed': 9574,
#  'provide': 90489,
#  'administrative': 8610,
#  'methodology': 70000,
#  'applications': 12878,
#  'technology': 108545,
#  'integration': 58575,
#  'operative': 79725,
#  'small': 102360,
#  'medium': 68894,
#  'sized': 102020,
#  'enterprises': 40576,
#  'slippers': 102261,
#  'established': 41848,
#  'bibliographic': 17436,
#  'determined': 34188,
#  'consolidated': 28364,
#  'preventive': 89290,
#  'measures': 68723,
#  'covid': 29731,
#  '19': 2088,
#  'actions': 8209,
#  'safe': 97955,
#  'return': 95711,
#  'centres': 23332,
#  'well': 118422,
#  'integrating': 58574,
#  'new': 76295,
#  'technologies': 108542,
#  'companies': 27307,
#  'together': 110942,
#  'situation': 101987,
#  'carried': 22265,
#  'survey': 106977,
#  'know': 62273,
#  'organizational': 80126,
#  'identification': 55950,
#  'productive': 89731,
#  'one': 79449,
#  'practices': 88546,
#  'good': 49782,
#  'hygiene': 55048,
#  'workplace': 119136,
#  'ensuring': 40494,
#  'conditions': 27872,
#  'standards': 104569,
#  'safer': 97964,
#  'environments': 40734,
#  'quick': 92314,
#  'responses': 95395,
#  'changes': 23910,
#  'external': 43371,
#  'strategies': 105306,
#  'must': 74051,
#  'develop': 34258,
#  'adverse': 8769,
#  'situations': 101990,
#  'acquired': 8112,
#  'optimizing': 79917,
#  'plant': 86538,
#  'ensures': 40493,
#  'production': 89725,
#  'reducing': 94000,
#  'shocks': 101100,
#  'article': 13769,
#  'elements': 39308,
#  'used': 115411,
#  'solve': 103015,
#  'followed': 45977,
#  'analyzing': 11257,
#  'frequently': 46706,
#  'applied': 12883,
#  'achieve': 7968,
#  'objective': 78353,
#  'developed': 34261,
#  'including': 57192,
#  '170': 1803,
#  'articles': 13770,
#  'performed': 84067,
#  'answers': 11967,
#  'given': 49096,
#  'growth': 50518,
#  'observed': 78453,
#  'five': 45263,
#  'especially': 41738,
#  'dynamic': 37553,
#  'unequal': 114388,
#  'multi': 73493,
#  'metaheuristic': 69768,
#  'solutions': 103008,
#  'eventually': 42584,
#  'gaps': 47796,
#  'identified': 55953,
#  'highlighting': 53207,
#  'lack': 62836,
#  'inclusion': 57197,
#  'distribution': 36086,
#  'standard': 104557,
#  'micro': 70357,
#  'msme': 73266,
#  'dynamics': 37557,
#  'ecuadorian': 38379,
#  'role': 96813,
#  'developing': 34265,
#  'national': 75119,
#  'economies': 38219,
#  'constantly': 28398,
#  'search': 99596,
#  'effective': 38687,
#  'tools': 111115,
#  'improve': 56960,
#  'methodologies': 69996,
#  'numerous': 78098,
#  'authors': 15084,
#  'explicitly': 43228,
#  'adapted': 8375,
#  'size': 102018,
#  'according': 7778,
#  'specific': 103543,
#  'needs': 75550,
#  'particular': 82714,
#  'procedures': 89609,
#  'adapting': 8380,
#  'financial': 45044,
#  'invest': 59567,
#  'substantial': 106172,
#  'improvements': 56966,
#  'seeks': 99816,
#  'characteristics': 23982,
#  'general': 48247,
#  'planning': 86531,
#  'decisions': 32668,
#  'proposes': 90187,
#  'tool': 111108,
#  'within': 118935,
#  'stages': 104489,
#  'included': 57188,
#  'validation': 115814,
#  'obtained': 78495,
#  'application': 12875,
#  'resulting': 95490,
#  'marked': 67901,
#  'differences': 34893,
#  'similarities': 101634,
#  'making': 67192,
#  'important': 56899,
#  'made': 66921,
#  'overview': 81057,
#  'technological': 108539,
#  'trends': 112176,
#  'logistics': 65644,
#  'retail': 95538,
#  'sector': 99720,
#  'recently': 93584,
#  'commerce': 27159,
#  'market': 67908,
#  'grown': 50516,
#  'rapidly': 93006,
#  'example': 42740,
#  'generated': 48281,
#  'sales': 98090,
#  'usd': 115407,
#  '504': 4936,
#  'billion': 17642,
#  'us': 115376,
#  'january': 60795,
#  '2020': 2498,
#  'july': 61272,
#  'representing': 95036,
#  'increase': 57288,
#  '11': 839,
#  '58': 5230,
#  'period': 84157,
#  '2019': 2495,
#  'forced': 46086,
#  'adopt': 8652,
#  'become': 16763,
#  'efficient': 38720,
#  '40': 4310,
#  'many': 67673,
#  'available': 15280,
#  'time': 110484,
#  'devoted': 34310,
#  'consuming': 28514,
#  'disproportionate': 35913,
#  'share': 100923,
#  'prime': 89364,
#  'topic': 111136,
#  'aims': 9577,
#  'present': 89125,
#  'show': 101177,
#  'focused': 45897,
#  'costs': 29505,
#  'usage': 115390,
#  'inventories': 59535,
#  'transport': 111938,
#  'algorithms': 10007,
#  'genetic': 48310,
#  'variants': 115976,
#  'simulation': 101714,
#  'supported': 106823,
#  'testing': 109272,
#  'proposals': 90180,
#  'big': 17561,
#  'data': 32194,
#  'omnichannel': 79355,
#  'continue': 28652,
#  'grow': 50512,
#  'considerably': 28321,
#  'decision': 32663,
#  'university': 114673,
#  'libraries': 64590,
#  'collection': 26811,
#  'publication': 91148,
#  'citation': 25393,
#  'patterns': 83048,
#  'recent': 93582,
#  'bibliometric': 17443,
#  'mining': 71296,
#  'presented': 89140,
#  'analyze': 11250,
#  'citations': 25395,
#  'moreover': 72724,
#  'criteria': 30257,
#  'acquiring': 8116,
#  'databases': 32200,
#  'allow': 10243,
#  'forming': 46256,
#  'base': 16354,
#  'unfortunately': 114450,
#  'scattered': 98870,
#  'determine': 34187,
#  'discovery': 35644,
#  'helps': 52335,
#  'subscription': 106097,
#  'acquisition': 8117,
#  'fink': 45118,
#  'conjunction': 28175,
#  'compile': 27433,
#  'relevant': 94606,
#  '167': 1741,
#  '2016': 2487,
#  'matrix': 68292,
#  'perform': 84051,
#  'metadata': 69753,
#  'content': 28587,
#  'among': 10926,
#  'primary': 89356,
#  'results': 95491,
#  'stands': 104583,
#  'number': 78076,
#  'vosviewer': 117542,
#  'outstanding': 80793,
#  'significant': 101449,
#  'aid': 9541,
#  'need': 75539,
#  'optimize': 79912,
#  'daily': 31986,
#  'tasks': 108233,
#  'became': 16738,
#  'mainly': 67131,
#  'requirement': 95122,
#  'stay': 104727,
#  'competitive': 27420,
#  'technique': 108524,
#  'improved': 56962,
#  'complex': 27475,
#  'susceptible': 107008,
#  'interventions': 59190,
#  'usual': 115471,
#  'workflow': 119118,
#  'hence': 52548,
#  'flps': 45677,
#  'emerged': 39666,
#  'various': 116018,
#  'known': 62288,
#  'searching': 99605,
#  'still': 105043,
#  'none': 77171,
#  'manage': 67407,
#  'factor': 43715,
#  'solution': 103006,
#  'compiled': 27434,
#  'modern': 72026,
#  'options': 79925,
#  'existing': 43011,
#  'current': 31164,
#  'reviews': 95813,
#  'widely': 118690,
#  'view': 116854,
#  'select': 99955,
#  '2015': 2486,
#  'allowed': 10248,
#  'final': 45024,
#  'sample': 98262,
#  '133': 1233,
#  'two': 113404,
#  'strings': 105466,
#  'result': 95482,
#  'manners': 67582,
#  'already': 10380,
#  'former': 46244,
#  'proprietary': 90203,
#  'matlab': 68267,
#  'cplex': 29821,
#  'lingo': 64968,
#  'varies': 116004,
#  'language': 63178,
#  'programming': 89884,
#  'depending': 33634,
#  'researcher': 95171,
#  'domain': 36519,
#  'furthermore': 47297,
#  'find': 45063,
#  'part': 82659,
#  'internal': 58944,
#  'linear': 64925,
#  'seek': 99812,
#  'levels': 64424,
#  'profit': 89811,
#  'projections': 89922,
#  'therefore': 109755,
#  'essential': 41813,
#  'products': 89746,
#  'manufactured': 67657,
#  'raw': 93144,
#  'materials': 68225,
#  'availability': 15278,
#  'improving': 56969,
#  'applying': 12889,
#  'balanced': 15966,
#  'plan': 86485,
#  'objectives': 78355,
#  'related': 94547,
#  'maximization': 68388,
#  'includes': 57190,
#  'description': 33913,
#  'studied': 105580,
#  'definition': 32958,
#  'executed': 42893,
#  'gurobi': 50918,
#  'solver': 103023,
#  'provided': 90490,
#  'discussion': 35696,
#  'sensitivity': 100276,
#  'several': 100720,
#  'works': 119140,
#  'dedicated': 32830,
#  'obtaining': 78499,
#  'economic': 38207,
#  'country': 29638,
#  'main': 67128,
#  'understand': 114277,
#  'terms': 109127,
#  'utilize': 115536,
#  'practical': 88538,
#  'methodological': 69993,
#  'filters': 45006,
#  'later': 63371,
#  'carry': 22280,
#  'procedure': 89608,
#  'performing': 84070,
#  'synthesis': 107547,
#  'found': 46394,
#  'vary': 116036,
#  'optimized': 79913,
#  'frequent': 46702,
#  'cost': 29471,
#  'minimization': 71282,
#  'integer': 58546,
#  'markov': 67930,
#  'chains': 23812,
#  'demand': 33292,
#  'forecasting': 46113,
#  'machine': 66696,
#  'learning': 63771,
#  'due': 37291,
#  'close': 25958,
#  'relationship': 94557,
#  'operational': 79713,
#  'considered': 28334,
#  'organizations': 80128,
#  'difficulty': 34929,
#  'generating': 48284,
#  'forecasts': 46114,
#  'volatility': 117431,
#  'caused': 22731,
#  'short': 101133,
#  'product': 89721,
#  'life': 64675,
#  'cycles': 31465,
#  'special': 103510,
#  'competitions': 27418,
#  'beginning': 16836,
#  'traditional': 111547,
#  'statistical': 104696,
#  'artificial': 13790,
#  'intelligence': 58610,
#  'opened': 79648,
#  'catalog': 22498,
#  'prediction': 88797,
#  'currently': 31165,
#  'high': 53179,
#  'precision': 88703,
#  'explores': 43259,
#  'ml': 71737,
#  'generate': 48280,
#  'regression': 94332,
#  'ridge': 96286,
#  'lasso': 63345,
#  'nearest': 75433,
#  'neighbor': 75619,
#  'support': 106822,
#  'vector': 116188,
#  'svr': 107114,
#  'forest': 46155,
#  'rf': 95899,
#  'end': 40037,
#  'series': 100468,
#  'inputs': 58239,
#  'google': 49792,
#  'method': 69982,
#  'higher': 53190,
#  'purely': 91447,
#  'basic': 16373,
#  'additionally': 8422,
#  'obtain': 78492,
#  'lower': 65948,
#  'error': 41485,
#  'metrics': 70123,
#  'mse': 73248,
#  '09787': 521,
#  '09682': 513,
#  'rmse': 96589,
#  '31285': 3704,
#  '31117': 3692,
#  'rse': 97346,
#  '32977': 3813,
#  '32800': 3807,
#  'respectively': 95357,
#  'meanwhile': 68707,
#  'reduces': 93997,
#  '15': 1481,
#  'corporate': 29235,
#  'social': 102715,
#  'responsibility': 95397,
#  'quality': 92130,
#  'tdabc': 108434,
#  'costing': 29497,
#  'system': 107607,
#  'assembly': 14216,
#  'purpose': 91481,
#  'paper': 82123,
#  'potential': 88308,
#  'driven': 37026,
#  'activity': 8239,
#  'value': 115867,
#  'integrate': 58571,
#  'csr': 30706,
#  'qm': 91961,
#  'provides': 90495,
#  'valuable': 115860,
#  'insights': 58325,
#  'sub': 105666,
#  'equations': 41182,
#  'framework': 46556,
#  'four': 46410,
#  'implementation': 56858,
#  'scenarios': 98905,
#  'valuation': 115864,
#  'referents': 94092,
#  'subject': 105909,
#  'iso': 60153,
#  'ethos': 42154,
#  'institute': 58443,
#  'electrostatic': 39273,
#  'discharge': 35561,
#  'control': 28764,
#  'programs': 89885,
#  'tv': 113329,
#  'assembler': 14212,
#  'highlight': 53205,
#  'extended': 43341,
#  'environmental': 40727,
#  'occupational': 78585,
#  'safety': 97966,
#  'health': 52067,
#  'administration': 8607,
#  'consequently': 28294,
#  'managers': 67421,
#  'simulate': 101710,
#  'incorporating': 57279,
#  'thus': 110271,
#  'decide': 32636,
#  'degree': 33071,
#  'corresponding': 29322,
#  'increases': 57291,
#  'maximum': 68394,
#  '12': 1012,
#  'socially': 102732,
#  'responsible': 95399,
#  'originality': 80214,
#  'although': 10451,
#  'theoretical': 109710,
#  'easily': 37862,
#  'implement': 56850,
#  'evaluate': 42524,
#  'mapping': 67708,
#  'modeling': 71994,
#  'highly': 53210,
#  'globalized': 49296,
#  'world': 119151,
#  'affected': 9002,
#  'policies': 87321,
#  'latent': 63369,
#  'pandemic': 82013,
#  'organize': 80129,
#  'reorganize': 94849,
#  'correct': 29267,
#  'led': 63863,
#  'administrators': 8614,
#  'resourceful': 95338,
#  'guide': 50834,
#  'towards': 111361,
#  'fulfilling': 47094,
#  'alternative': 10438,
#  'previous': 89303,
#  'bpm': 19421,
#  'reengineering': 94041,
#  'bpr': 19432,
#  'event': 42578,
#  'chain': 23808,
#  'epc': 40849,
#  'analyzes': 11255,
#  'compatibility': 27371,
#  'affinity': 9027,
#  'addition': 8419,
#  'advantages': 8754,
#  'disadvantages': 35494,
#  'adaptability': 8366,
#  'uses': 115425,
#  'qualitative': 92126,
#  'qualification': 92118,
#  'matrices': 68286,
#  'answer': 11963,
#  'improvement': 56964,
#  'create': 30048,
#  'hybrid': 54710,
#  'algorithm': 10004,
#  'supply': 106819,
#  'best': 17240,
#  'plethora': 86808,
#  'nha': 76422,
#  'sco': 99261,
#  'benefits': 17021,
#  'function': 47157,
#  'convergence': 28829,
#  'utilized': 115537,
#  'flow': 45645,
#  'material': 68210,
#  'delivered': 33244,
#  'clients': 25801,
#  'satisfy': 98591,
#  'maximize': 68389,
#  'service': 100601,
#  'level': 64415,
#  'minimize': 71283,
#  'scrap': 99356,
#  'compared': 27341,
#  'performs': 84071,
#  'faster': 44056,
#  'converges': 28837,
#  'fewer': 44701,
#  'iterations': 60478,
#  'similar': 101631,
#  'even': 42571,
#  'better': 17289,
#  'tested': 109257,
#  'generic': 48297,
#  'benchmarking': 16981,
#  'demanding': 33298,
#  'efficiently': 38721,
#  'properly': 90109,
#  'compete': 27400,
#  'customer': 31243,
#  'satisfaction': 98584,
#  'presents': 89151,
#  'creation': 30055,
#  'common': 27204,
#  'strategic': 105302,
#  'took': 111107,
#  'reference': 94080,
#  'diagramming': 34513,
#  'validated': 115811,
#  'comparisons': 27349,
#  'ideas': 55922,
#  'creating': 30052,
#  'large': 63260,
#  'scale': 98780,
#  'corpus': 29256,
#  'natural': 75161,
#  'processing': 89634,
#  'boom': 19115,
#  'introducing': 59425,
#  'aspects': 14123,
#  'everyday': 42598,
#  'field': 44876,
#  'consists': 28356,
#  'nlp': 76816,
#  'human': 54488,
#  'key': 61887,
#  'component': 27514,
#  'learn': 63765,
#  'constructing': 28461,
#  'feed': 44339,
#  'emerges': 39673,
#  'finding': 45068,
#  'languages': 63181,
#  'english': 40339,
#  'producing': 89719,
#  'resource': 95334,
#  'construction': 28462,
#  'phases': 84919,
#  'designed': 33987,
#  'along': 10330,
#  'considerations': 28331,
#  'taken': 107920,
#  'implemented': 56862,
#  'consist': 28344,
#  'characterization': 23984,
#  'collecting': 26810,
#  'cleaning': 25708,
#  'translation': 111843,
#  'storage': 105203,
#  'automatic': 15165,
#  'translators': 111848,
#  'take': 107918,
#  'advantage': 8750,
#  'vast': 116088,
#  'amount': 10950,
#  'non': 77063,
#  'spanish': 103392,
#  '000': 1,
#  'opinions': 79792,
#  'evaluations': 42533,
#  'build': 20275,
#  'lean': 63753,
#  'bicycle': 17494,
#  'line': 64915,
#  'industries': 57582,
#  'continually': 28649,
#  'systems': 107635,
#  'differentiating': 34911,
#  'efficiency': 38719,
#  'competitiveness': 27423,
#  'lm': 65382,
#  'philosophy': 85113,
#  'contributes': 28750,
#  'differentiators': 34914,
#  'focusing': 45899,
#  'elimination': 39385,
#  'waste': 118038,
#  'delivery': 33248,
#  'times': 110505,
#  'evident': 42622,
#  'called': 21218,
#  'stream': 105352,
#  'map': 67679,
#  'vsm': 117660,
#  'requirements': 95123,
#  'facilitating': 43695,
#  'e26': 37735,
#  'selected': 99957,
#  'illustrative': 56411,
#  'purposes': 91486,
#  '5s': 5386,
#  'maintain': 67143,
#  'tidiness': 110381,
#  'cleanliness': 25709,
#  'agile': 9280,
#  'balancing': 15970,
#  'lines': 64952,
#  'getting': 48815,
#  'reduction': 94006,
#  '14': 1346,
#  'cycle': 31461,
#  '66': 5687,
#  'lead': 63714,
#  'mixed': 71688,
#  'push': 91521,
#  'pull': 91255,
#  'warehouse': 117953,
#  'unification': 114539,
#  'involved': 59646,
#  'future': 47357,
#  'legitimacy': 63939,
#  'confirmed': 27994,
#  'validating': 115813,
#  'toward': 111360,
#  'sustainability': 107034,
#  'scorecard': 99310,
#  'managing': 67423,
#  'conceptual': 27729,
#  'sbsc': 98733,
#  'track': 111508,
#  'measure': 68716,
#  'monitor': 72328,
#  'alignment': 10041,
#  'dashboards': 32179,
#  'goals': 49637,
#  'threefold': 110156,
#  'proposal': 90179,
#  'scheme': 98973,
#  'assess': 14233,
#  'local': 65519,
#  'regional': 94278,
#  'implementations': 56859,
#  'previously': 89304,
#  'incorporate': 57276,
#  'dashboard': 32177,
#  'steps': 104879,
#  'depth': 33747,
#  'principles': 89408,
#  'dimensions': 35149,
#  'stakeholders': 104519,
#  'means': 68702,
#  'consistently': 28353,
#  'incorporates': 57278,
#  'subcategories': 105722,
#  'assessment': 14240,
#  'sustainable': 107035,
#  'aligned': 10038,
#  'standardize': 104564,
#  'estimates': 41918,
#  'multiple': 73720,
#  'real': 93384,
#  'cases': 22375,
#  'compares': 27343,
#  'performance': 84054,
#  'measurements': 68721,
#  'conventional': 28821,
#  'chronometer': 24920,
#  'estimating': 41920,
#  'without': 118941,
#  'reconducting': 93732,
#  'international': 58955,
#  'labour': 62793,
#  'ilo': 56416,
#  'baseline': 16364,
#  'structured': 105542,
#  'selection': 99960,
#  'registration': 94312,
#  'observation': 78441,
#  'calculation': 21139,
#  'estimation': 41921,
#  'belong': 16946,
#  'motorcycles': 72978,
#  'television': 108768,
#  'sets': 100680,
#  'printed': 89413,
#  'circuit': 25282,
#  'boards': 18860,
#  'pcb': 83251,
#  'bicycles': 17495,
#  'motorcycle': 72977,
#  'fourteen': 46421,
#  'seven': 100710,
#  'estimate': 41916,
#  'assembling': 14215,
#  'front': 46853,
#  'parts': 82756,
#  'rear': 93453,
#  'types': 113455,
#  'never': 76288,
#  'exceeded': 42770,
#  '10': 587,
#  'measured': 68718,
#  'pcbs': 83253,
#  'nonlinear': 77275,
#  'appropriate': 12940,
#  'predictions': 88798,
#  'logic': 65630,
#  'constructed': 28460,
#  'represent': 95013,
#  'limitations': 64832,
#  'implications': 56876,
#  'confidentiality': 27964,
#  'names': 74711,
#  'services': 100605,
#  'omitted': 79343,
#  'consulted': 28497,
#  'refer': 94072,
#  'representation': 95024,
#  'empirical': 39795,
#  'supporting': 106826,
#  'guidelines': 50839,
#  'osh': 80469,
#  'concern': 27743,
#  'since': 101745,
#  'workers': 119116,
#  'welfare': 118420,
#  'operating': 79710,
#  'manner': 67581,
#  'synthesized': 107552,
#  'building': 20279,
#  '2009': 2444,
#  '2018': 2492,
#  '96': 6911,
#  'identifies': 55958,
#  'challenges': 23851,
#  'pestel': 84538,
#  'concept': 27721,
#  'meanings': 68699,
#  'true': 112815,
#  'comes': 27105,
#  'complexity': 27485,
#  'implementing': 56864,
#  'living': 65280,
#  'honoring': 53916,
#  'constitutional': 28424,
#  'rights': 96341,
#  ...}

# %%
'covid' in tfidf.vocabulary_
# Out:
# True

# %%
tfidf.vocabulary_['intelligence']
# Out:
# 58610

# %%
print(matrix)
# Out:
#   (0, 103362)	0.09901086259320825
#   (0, 43175)	0.06663115536333616
#   (0, 8238)	0.06547821775297065
#   (0, 8205)	0.08270357649366306
#   (0, 92948)	0.09776080408384201
#   (0, 43095)	0.12266942781233617
#   (0, 75983)	0.07326111334114051
#   (0, 41850)	0.09839959075191457
#   (0, 10251)	0.06242527840617196
#   (0, 8382)	0.10080393291937903
#   (0, 45490)	0.10703542853606968
#   (0, 57294)	0.09620306620182087
#   (0, 109205)	0.12358305820200322
#   (0, 30058)	0.12887263277652924
#   (0, 32946)	0.09064033758494239
#   (0, 19333)	0.12632474266794103
#   (0, 110901)	0.09387844285454777
#   (0, 40726)	0.06365927967255641
#   (0, 46200)	0.07837554497149288
#   (0, 16854)	0.06647102555164909
#   (0, 27971)	0.09944483590059525
#   (0, 56755)	0.05976030951144175
#   (0, 35438)	0.07796418515942816
#   (0, 57841)	0.04979480373307328
#   (0, 115869)	0.06281040494452338
#   :	:
#   (37568, 13991)	0.3796167120676995
#   (37568, 106425)	0.143221841833236
#   (37568, 101184)	0.0661446741092075
#   (37568, 42020)	0.12522927158507755
#   (37568, 108828)	0.08919727824197063
#   (37568, 24180)	0.0931535929290928
#   (37568, 104565)	0.2083565981841275
#   (37568, 95214)	0.11909745883400566
#   (37568, 75540)	0.09941156138646846
#   (37568, 102747)	0.0920252993131891
#   (37568, 75480)	0.08119696470196898
#   (37568, 34184)	0.10792734917876708
#   (37568, 65942)	0.0647722296654737
#   (37568, 10771)	0.08852067223602855
#   (37568, 96341)	0.10409680984210878
#   (37568, 68721)	0.1007331433734692
#   (37568, 63260)	0.0812906517898518
#   (37568, 69982)	0.1585226674618774
#   (37568, 88703)	0.1175134408073998
#   (37568, 89746)	0.09349711972021382
#   (37568, 28587)	0.08653203522386532
#   (37568, 110484)	0.0595173738357103
#   (37568, 104557)	0.0900695005730475
#   (37568, 16356)	0.04960722818903458
#   (37568, 105582)	0.06618236489733823

# %% [markdown]
# ### 4) Almacenar el modelo en un diccionario

# %% [markdown]
# #### Definir el modelo

# %%
model = {
    'vocabulary': tfidf.vocabulary_,
    'matrix': matrix,
    'indexes': corpus['doc_id'].to_list()
}

# %% [markdown]
# #### Definir la ruta del modelo

# %%
basePath = 'resources/models/tf-idf/'
version = 'v10.0'
modelPath = basePath+"model-"+version+".pkl"

# %% [markdown]
# #### Almacenar el modelo

# %%
with open(modelPath, "wb") as fp:  
    pickle.dump(model, fp)
